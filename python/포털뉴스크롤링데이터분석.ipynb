# %%
from matplotlib import font_manager, rc

font_path = '/Windows/Fonts/H2GSRB.TTF'
font = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family = font)

# %%
import requests
import bs4

url = 'https://news.daum.net/'
res = requests.get(url)

# print(res.text)

soup = bs4.BeautifulSoup(res.text)
# print(soup)
# data = soup.select('a')
data = soup.find_all('a')
# print(data)

# %%
category_url = {
    '메인': ['https://news.daum.net/'],
    '사회': ['https://news.daum.net/society'],
    '정치': ['https://news.daum.net/politics'],
    '경제': ['https://news.daum.net/economic'],
    '국제': ['https://news.daum.net/foreign'],
    '문화': ['https://news.daum.net/culture'],
    'IT': ['https://news.daum.net/digital'] 
}

# %%
for i, j in category_url.items():
    res = requests.get(j[0])
    j.append(res.text)

# %%
# print(category_url['문화'])

# %%
temp = []

for i, j in category_url.items():
    soup = bs4.BeautifulSoup(j[1])
    
    for n in soup.find_all('span', attrs={'class':'info_cp'}):
        temp.append(n.text.strip())
        
    for n in soup.find_all('span', attrs={'class':'info_thumb'}):
        if n.find('a') == None:
            
            if '\n' in n.text.strip():
                temp.append(n.text.strip().split('\n')[0])
            elif n.text.strip() == '':
                temp.append(n.find('img', alt = True)['alt'])
            else:
                temp.append(n.text.strip())

# %%
print(temp)
# Out:
# ['경제', '국제', '경제', '경제', '경제', '사회', '사회', '경제', '경제', '정치', '사회', '국제', '정치', '국제', '경제', '경제', '사회', '정치', '국제', '정치', 'YTN', '노컷뉴스', 'SBS', '지디넷코리아', '한겨레21', '데일리안', '전자신문', '머니투데이', 'YTN', '연합뉴스', '뉴시스', '머니투데이', '시사저널', '연합뉴스', '뉴스1', '머니투데이', '뉴시스', '연합뉴스', '연합뉴스', '국민일보', '오마이뉴스', '국제신문', '아시아경제', '시사저널', 'YTN', '오마이뉴스', '노컷뉴스', 'SBS', '한겨레21', 'SBS', '서울신문', 'KBS', 'YTN', 'JTBC', '뉴스1', '연합뉴스', '한국일보', '더팩트', '뉴시스', '뉴스1', '뉴시스', '오마이뉴스', '조선일보', 'kbc광주방송', '오마이뉴스', '매일경제', 'YTN', '뉴스1', '서울신문', '뉴스1', 'kbc광주방송', 'SBS', '시사IN', '오마이뉴스', '서울신문', 'MBN', 'KBS', '채널A', '뉴스1', '머니투데이', '뉴스1', '조선비즈', '비즈니스워치', '이데일리', '뉴스1', '연합뉴스', '파이낸셜뉴스', '뉴스1', '연합뉴스', '조선비즈', '더스쿠프', '뉴스1', '국제신문', '데일리안', '채널A', '한국경제', '한국경제', 'SBS', 'JTBC', '헤럴드경제', '한국경제TV', '서울경제', 'SBS Biz', '뉴스1', '아시아경제', '뉴스1', '뉴스1', '연합뉴스', '연합뉴스', '국민일보', '연합뉴스', '한겨레', '연합뉴스', '머니투데이', '뉴시스', '조선비즈', '국제신문', '뉴시스', '머니투데이', '뉴시스', '세계일보', '서울경제', 'SBS', '서울신문', 'KBS', 'KBS', '서울신문', '오마이뉴스', '머니S', '서울신문', '한국일보', '동아일보', 'SBS', '서울경제', '뉴시스', '농민신문', '헤럴드경제', '문화일보', '헬스조선', '이데일리', '코메디닷컴', '한겨레21', '데일리안', 'JIBS', '키즈맘', '엘르', '헬스조선', '베이비뉴스', '로피시엘 코리아', '한겨레21', '코메디닷컴', '웨딩21뉴스', 'JTBC', '대전일보', '조선일보', '경향신문', '경향신문', '대전일보', '경향신문', '세계일보', '디지털타임스', '국제신문', '지디넷코리아', '조선일보', '파이낸셜뉴스', '데일리안', '뉴스1', '헤럴드경제', '한겨레', '뉴시스', '뉴스1', 'YTN', '서울경제', '뉴시스', '지디넷코리아', '연합뉴스', '전자신문', '한국경제', 'IT동아', '아이뉴스24', '한국경제', '조선비즈', '조선일보', '전자신문', '이데일리', '아이뉴스24']

# %%
# print(category_url['IT'])

# %%
temp_a = []
soup = bs4.BeautifulSoup(category_url['IT'][1])
for i in soup.find_all('span', attrs = {'class':'info_thumb'}):
    if i.find('a') == None:
        print(i.text.strip())
        temp_a.append(i.text.strip())

print(temp_a)
# Out:
# YTN
# 서울경제
# 뉴시스
# 지디넷코리아
# 연합뉴스
# 전자신문
# 한국경제
# IT동아
# 아이뉴스24
# 한국경제
# 조선비즈
# 조선일보
# 전자신문
# 이데일리
# 아이뉴스24
# ['YTN', '서울경제', '뉴시스', '지디넷코리아', '연합뉴스', '전자신문', '한국경제', 'IT동아', '아이뉴스24', '한국경제', '조선비즈', '조선일보', '전자신문', '이데일리', '아이뉴스24']

# %%
for i, j in category_url.items():
    soup = bs4.BeautifulSoup(j[1])
    # 언론사 리스트
    temp = []
    
    for n in soup.find_all('span', attrs={'class':'info_cp'}):
        temp.append(n.text.strip())
        
    for n in soup.find_all('span', attrs={'class':'info_thumb'}):
        if n.find('a') == None:
            
            if '\n' in n.text.strip():
                temp.append(n.text.strip().split('\n')[0])
            elif n.text.strip() == '':
                temp.append(n.find('img', alt = True)['alt'])
            else:
                temp.append(n.text.strip())
                
    j.append(temp)

# %%
print(category_url['IT'][2])
# Out:
# ['국제신문', '지디넷코리아', '조선일보', '파이낸셜뉴스', '데일리안', '뉴스1', '헤럴드경제', '한겨레', '뉴시스', '뉴스1', 'YTN', '서울경제', '뉴시스', '지디넷코리아', '연합뉴스', '전자신문', '한국경제', 'IT동아', '아이뉴스24', '한국경제', '조선비즈', '조선일보', '전자신문', '이데일리', '아이뉴스24']

# %%
import wordcloud

text = ' '.join(category_url['경제'][2])
wc = wordcloud.WordCloud(font_path = font_path, background_color = 'white')
wc.generate_from_text(text)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
import requests
import bs4

url = 'https://news.daum.net/'
res = requests.get(url)

# %%
# 모든 언론사 리스트 
data = []
for i, j in category_url.items():
    if i != '메인':
        data.extend(j[2])
    
unique_data = list(set(data))

print(unique_data)
# Out:
# ['경향신문', '시사저널', '데일리안', '국제신문', '문화일보', '엘르', '서울경제', '뉴스1', '더팩트', '키즈맘', '아시아경제', '세계일보', '시사IN', '한국경제', 'JIBS', '디지털타임스', 'kbc광주방송', '파이낸셜뉴스', '노컷뉴스', '한겨레', '오마이뉴스', 'MBN', '이데일리', '로피시엘 코리아', '더스쿠프', '국민일보', 'JTBC', 'YTN', '코메디닷컴', '헤럴드경제', '동아일보', 'IT동아', '조선일보', '비즈니스워치', '아이뉴스24', '연합뉴스', '머니S', '헬스조선', '한겨레21', '한국일보', '머니투데이', '채널A', '지디넷코리아', '웨딩21뉴스', '한국경제TV', '전자신문', 'KBS', '매일경제', '베이비뉴스', '서울신문', '조선비즈', '농민신문', '뉴시스', '대전일보', 'SBS Biz', 'SBS']

# %%
# 분야별
rank = {}
for i in unique_data:
    rank[i]=0

for i in category_url['IT'][2]:
    rank[i] += 1
    
print(rank)
# Out:
# {'경향신문': 0, '시사저널': 0, '데일리안': 1, '국제신문': 1, '문화일보': 0, '엘르': 0, '서울경제': 1, '뉴스1': 2, '더팩트': 0, '키즈맘': 0, '아시아경제': 0, '세계일보': 0, '시사IN': 0, '한국경제': 2, 'JIBS': 0, '디지털타임스': 0, 'kbc광주방송': 0, '파이낸셜뉴스': 1, '노컷뉴스': 0, '한겨레': 1, '오마이뉴스': 0, 'MBN': 0, '이데일리': 1, '로피시엘 코리아': 0, '더스쿠프': 0, '국민일보': 0, 'JTBC': 0, 'YTN': 1, '코메디닷컴': 0, '헤럴드경제': 1, '동아일보': 0, 'IT동아': 1, '조선일보': 2, '비즈니스워치': 0, '아이뉴스24': 2, '연합뉴스': 1, '머니S': 0, '헬스조선': 0, '한겨레21': 0, '한국일보': 0, '머니투데이': 0, '채널A': 0, '지디넷코리아': 2, '웨딩21뉴스': 0, '한국경제TV': 0, '전자신문': 2, 'KBS': 0, '매일경제': 0, '베이비뉴스': 0, '서울신문': 0, '조선비즈': 1, '농민신문': 0, '뉴시스': 2, '대전일보': 0, 'SBS Biz': 0, 'SBS': 0}

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10, 10))

for i in category_url.keys():
    rank = {}
    
    for j in unique_data:
        rank[j] = 0
        
    for j in category_url[i][2]:
        if i == '메인':
            continue
        rank[j] += 1
        
    x = rank.keys()
    y = rank.values()
    plt.bar(x,y,label=i)
    
plt.xticks(rotation=60)
plt.legend()
plt.title('븐야별 언론사 랭킹')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#전체 데이터 출력
print(data)
# Out:
# ['경제', '사회', '정치', '경제', '국제', '국제', '국제', '정치', '국제', 'IT', '국제', '사회', '정치', '국제', '경제', '국제', '정치', '경제', '국제', '경제', '한국경제', 'YTN', '한국경제', '머니투데이', '뉴시스', '한국경제', '헤럴드경제', '노컷뉴스', None, None, None, None, None, None, None, None, None, None, '뉴스1', '동아일보', '아시아경제', '연합뉴스', 'MBC', '뉴스1', '연합뉴스TV', 'YTN', '서울신문', 'YTN', 'MBC', 'KBS', '한겨레', '경향신문', 'SBS', None, None, None, None, None, None, None, None, None, None, '뉴스1', '오마이뉴스', '뉴시스', '뉴스1', 'MBC', '연합뉴스', '뉴스1', 'kbc광주방송', 'SBS', '시사IN', '오마이뉴스', '서울신문', 'MBN', 'KBS', '채널A', None, None, None, None, None, None, None, None, None, None, '뉴시스', '한국경제', '뉴시스', '동아일보', '한겨레', '뉴스1', '한국경제', '한국경제', 'SBS', 'JTBC', '헤럴드경제', '한국경제TV', '서울경제', 'SBS Biz', '프레시안', None, None, None, None, None, None, None, None, None, None, '뉴스1', '뉴시스', '연합뉴스', '뉴시스', '뉴시스', '중앙일보', '뉴시스', '서울신문', 'KBS', 'KBS', '서울신문', '오마이뉴스', 'JTBC', 'SBS Biz', 'KBS', None, None, None, None, None, None, None, None, None, None, '뉴시스', '코메디닷컴', '경향신문', '농민신문', '헤럴드경제', '문화일보', '하이닥', '코메디닷컴', '키즈맘', '헬스조선', '웨딩21뉴스', '여성동아', '메종', '투어코리아', 'JTBC', '대전일보', '조선일보', '경향신문', '경향신문', '대전일보', '경향신문', '세계일보', '디지털타임스', None, None, None, None, None, None, None, None, None, None, '연합뉴스', '파이낸셜뉴스', '데일리안', '뉴스1', '헤럴드경제', '한겨레', '아이뉴스24', '한국경제', '조선비즈', '조선일보', '전자신문', '한국경제', '이데일리', '아이뉴스24', '전자신문']

# %%
# 전체 랭킹
rank = {}

for i in data:
    if rank.get(i) == None:
        rank[i] = 1
    else:
        rank[i] += 1
        
print(rank)
# Out:
# {'YTN': 5, '연합뉴스': 12, '뉴시스': 10, '머니투데이': 5, '시사저널': 2, '뉴스1': 15, '국민일보': 2, '오마이뉴스': 6, '국제신문': 4, '아시아경제': 2, '노컷뉴스': 1, 'SBS': 6, '한겨레21': 3, '서울신문': 6, 'KBS': 4, 'JTBC': 3, '한국일보': 2, '더팩트': 1, '조선일보': 4, 'kbc광주방송': 2, '매일경제': 1, '시사IN': 1, 'MBN': 1, '채널A': 2, '조선비즈': 4, '비즈니스워치': 1, '이데일리': 3, '파이낸셜뉴스': 2, '더스쿠프': 1, '데일리안': 3, '한국경제': 4, '헤럴드경제': 3, '한국경제TV': 1, '서울경제': 4, 'SBS Biz': 1, '한겨레': 2, '세계일보': 2, '머니S': 1, '동아일보': 1, '농민신문': 1, '문화일보': 1, '헬스조선': 2, '코메디닷컴': 2, 'JIBS': 1, '키즈맘': 1, '엘르': 1, '베이비뉴스': 1, '로피시엘 코리아': 1, '웨딩21뉴스': 1, '대전일보': 2, '경향신문': 3, '디지털타임스': 1, '지디넷코리아': 2, '전자신문': 2, 'IT동아': 1, '아이뉴스24': 2}

# %%
plt.figure(figsize=(10,10))

x = rank.keys()
y = rank.values()

plt.bar(x,y)

plt.xticks(rotation=90)
plt.title('전체 분야 언론사 랭킹')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10,10))

x = rank.keys()
y = rank.values()

plt.pie(y, labels = x)

plt.title('전체 분야 언론사 랭킹')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
